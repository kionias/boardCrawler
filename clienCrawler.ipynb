# %% [markdown]
# Anlalyze times and hits of articles to upload
# a article in a timely manner to find a mentor

# %%
# 기본 사용법 (pip install beautifulsoup4)
from bs4 import BeautifulSoup
# from 모듈이름 import 클래스 이름
import urllib.request as req
import pandas as pd
import time

# %%
# 모두의 공원 URL
url = 'https://www.clien.net/service/board/park'
res = req.urlopen(url) #소스를 res로 넣는다
soup = BeautifulSoup(res, "html.parser")

# %%
recommend = soup.select("div.list_content > div > div.list_symph > span")
category = soup.select("div > div.list_title > a > span.shortname.fixed")
title = soup.select("div > div.list_title > a > span.subject_fixed")
reply = soup.select("div.list_content > div > div.list_title > a")
writer = soup.select(" div.list_content > div > div.list_author")
viewCnt = soup.select("div.list_content > div > div.list_hit > span ")
dateTime =soup.select("div.list_content > div > div.list_time > span")
docNo = soup.select("div.list_content > div > div.list_title > a.list_subject")

# %%
# print("recommend : {}".format(recommend))
# print("latestDocNo : {}".format(docNo))
docAddr = docNo[0]["href"]
print("latestDocNo : {}".format(docAddr) )
type(docAddr )
# Out:
# latestDocNo : /service/board/park/15037474?od=T31&po=0&category=&groupCd=
# str

# %%
# 라이터가 이미지인 경우에
# 리플이 안달린 경우에
#reply = soup.select("div.list_content > div > div.list_title > a")
#reply[1].text # try except
# 에러  나면 0으로 추가하도록

# %%
#writer = soup.select(" div.list_content > div > div.list_author")

#print(writer[0])

#str(writer[28]).split('img alt="')[1].split('"')[0]

#len(writer[2].text.split("\n")[3])
#그림 없는경우
#writer[2].text.split("\n")[3]
#writer[28].text.split("\n")[3]

# 그림이 있는 경우는 len이 0 이경우에는 
#str(writer[28]).split('img alt="')[1].split('"')[0]

# %%
info=pd.DataFrame()
accum=pd.DataFrame()

for i in range(0,100):
    
    url = "https://www.clien.net/service/group/community?&od=T31&po=" + str(i)
    print(url)
    
    res = req.urlopen(url) #소스를 res로 넣는다
    soup = BeautifulSoup(res, "html.parser")

    recommend = soup.select("div.list_content > div > div.list_symph > span")
    category = soup.select("div > div.list_title > a > span.shortname.fixed")
    title = soup.select("div > div.list_title > a > span.subject_fixed")
    reply = soup.select("div.list_content > div > div.list_title > a")
    writer = soup.select(" div.list_content > div > div.list_author")
    viewCnt = soup.select("div.list_content > div > div.list_hit > span ")
    dateTime =soup.select("div.list_content > div > div.list_time > span")
    docNo = soup.select("div.list_content > div > div.list_title > a.list_subject")
    photoyn = soup.select("div.list_content > div > div.list_title")


    recList =[]
    catList =[]
    titList =[]
    repList =[]
    wriList =[]
    viewList =[]
    datList =[]
    docList = []
    phoList = []

    #print("soup : {}".format(soup) )
    #print("recommend : {}".format(recommend) )
    
    # 가끔 게시물이 30개가 아닌경우가 있음
    length=len(recommend)

    for ind in range(length):
        rec = recommend[ind].text
        cat = category[ind].text
        tit = title[ind].text      
        view = viewCnt[ind].text
        dat = dateTime[ind].text.split("\t")[13].rstrip('\n')
        doc = docNo[ind]["href"].split("/")[4].split("?")[0]
        
        # if there's photo in article, also class "icon"
        if len(str(photoyn[0]).split("icon"))==2:
            pho = "Y"
        else:
            pho = "N"
        
        # if there's no reply, no data
        try:
            int(reply[ind].text)
            rep = int(reply[ind].text)
        except:
            rep = 0

        # if someone's nickname is image
        
        if len(writer[ind].text.split("\n")[3]) == 0:
            wri = str(writer[ind]).split('img alt="')[1].split('"')[0]
        else:
            wri = writer[ind].text.split("\n")[3]

        recList.append(rec)
        catList.append(cat)
        titList.append(tit)
        repList.append(rep)
        wriList.append(wri)
        viewList.append(view)
        datList.append(dat)
        docList.append(doc)
        phoList.append(pho)

    # list into dataframe
    info = pd.DataFrame(columns=['추천수'],data = recList)
    info['게시판'] = catList
    info['제목'] = titList
    info['리플수'] = repList
    info['아이디'] = wriList
    info['조회수'] = viewList
    info['날짜'] = datList
    info['문서번호'] = docList
    info['사진유무'] = phoList
    
#    if len(info) != 30:
#        print("길이오류")
#        print(info)
    
    accum = pd.concat([accum,info])
    info =pd.DataFrame()
    
    time.sleep(0.3)
# Out:
# https://www.clien.net/service/group/community?&od=T31&po=0
# https://www.clien.net/service/group/community?&od=T31&po=1
# https://www.clien.net/service/group/community?&od=T31&po=2
# https://www.clien.net/service/group/community?&od=T31&po=3
# https://www.clien.net/service/group/community?&od=T31&po=4
# https://www.clien.net/service/group/community?&od=T31&po=5
# https://www.clien.net/service/group/community?&od=T31&po=6
# https://www.clien.net/service/group/community?&od=T31&po=7
# https://www.clien.net/service/group/community?&od=T31&po=8
# https://www.clien.net/service/group/community?&od=T31&po=9
# https://www.clien.net/service/group/community?&od=T31&po=10
# https://www.clien.net/service/group/community?&od=T31&po=11
# https://www.clien.net/service/group/community?&od=T31&po=12
# https://www.clien.net/service/group/community?&od=T31&po=13
# https://www.clien.net/service/group/community?&od=T31&po=14
# https://www.clien.net/service/group/community?&od=T31&po=15
# https://www.clien.net/service/group/community?&od=T31&po=16
# https://www.clien.net/service/group/community?&od=T31&po=17
# https://www.clien.net/service/group/community?&od=T31&po=18
# https://www.clien.net/service/group/community?&od=T31&po=19
# https://www.clien.net/service/group/community?&od=T31&po=20
# https://www.clien.net/service/group/community?&od=T31&po=21
# https://www.clien.net/service/group/community?&od=T31&po=22
# https://www.clien.net/service/group/community?&od=T31&po=23
# https://www.clien.net/service/group/community?&od=T31&po=24
# https://www.clien.net/service/group/community?&od=T31&po=25
# https://www.clien.net/service/group/community?&od=T31&po=26
# https://www.clien.net/service/group/community?&od=T31&po=27
# https://www.clien.net/service/group/community?&od=T31&po=28
# https://www.clien.net/service/group/community?&od=T31&po=29
# https://www.clien.net/service/group/community?&od=T31&po=30
# https://www.clien.net/service/group/community?&od=T31&po=31
# https://www.clien.net/service/group/community?&od=T31&po=32
# https://www.clien.net/service/group/community?&od=T31&po=33
# https://www.clien.net/service/group/community?&od=T31&po=34
# https://www.clien.net/service/group/community?&od=T31&po=35
# https://www.clien.net/service/group/community?&od=T31&po=36
# https://www.clien.net/service/group/community?&od=T31&po=37
# https://www.clien.net/service/group/community?&od=T31&po=38
# https://www.clien.net/service/group/community?&od=T31&po=39
# https://www.clien.net/service/group/community?&od=T31&po=40
# https://www.clien.net/service/group/community?&od=T31&po=41
# https://www.clien.net/service/group/community?&od=T31&po=42
# https://www.clien.net/service/group/community?&od=T31&po=43
# https://www.clien.net/service/group/community?&od=T31&po=44
# https://www.clien.net/service/group/community?&od=T31&po=45
# https://www.clien.net/service/group/community?&od=T31&po=46
# https://www.clien.net/service/group/community?&od=T31&po=47
# https://www.clien.net/service/group/community?&od=T31&po=48
# https://www.clien.net/service/group/community?&od=T31&po=49
# https://www.clien.net/service/group/community?&od=T31&po=50
# https://www.clien.net/service/group/community?&od=T31&po=51
# https://www.clien.net/service/group/community?&od=T31&po=52
# https://www.clien.net/service/group/community?&od=T31&po=53
# https://www.clien.net/service/group/community?&od=T31&po=54
# https://www.clien.net/service/group/community?&od=T31&po=55
# https://www.clien.net/service/group/community?&od=T31&po=56
# https://www.clien.net/service/group/community?&od=T31&po=57
# https://www.clien.net/service/group/community?&od=T31&po=58
# https://www.clien.net/service/group/community?&od=T31&po=59
# https://www.clien.net/service/group/community?&od=T31&po=60
# https://www.clien.net/service/group/community?&od=T31&po=61
# https://www.clien.net/service/group/community?&od=T31&po=62
# https://www.clien.net/service/group/community?&od=T31&po=63
# https://www.clien.net/service/group/community?&od=T31&po=64
# https://www.clien.net/service/group/community?&od=T31&po=65
# https://www.clien.net/service/group/community?&od=T31&po=66
# https://www.clien.net/service/group/community?&od=T31&po=67
# https://www.clien.net/service/group/community?&od=T31&po=68
# https://www.clien.net/service/group/community?&od=T31&po=69
# https://www.clien.net/service/group/community?&od=T31&po=70
# https://www.clien.net/service/group/community?&od=T31&po=71
# https://www.clien.net/service/group/community?&od=T31&po=72
# https://www.clien.net/service/group/community?&od=T31&po=73
# https://www.clien.net/service/group/community?&od=T31&po=74
# https://www.clien.net/service/group/community?&od=T31&po=75
# https://www.clien.net/service/group/community?&od=T31&po=76
# https://www.clien.net/service/group/community?&od=T31&po=77
# https://www.clien.net/service/group/community?&od=T31&po=78
# https://www.clien.net/service/group/community?&od=T31&po=79
# https://www.clien.net/service/group/community?&od=T31&po=80
# https://www.clien.net/service/group/community?&od=T31&po=81
# https://www.clien.net/service/group/community?&od=T31&po=82
# https://www.clien.net/service/group/community?&od=T31&po=83
# https://www.clien.net/service/group/community?&od=T31&po=84
# https://www.clien.net/service/group/community?&od=T31&po=85
# https://www.clien.net/service/group/community?&od=T31&po=86
# https://www.clien.net/service/group/community?&od=T31&po=87
# https://www.clien.net/service/group/community?&od=T31&po=88
# https://www.clien.net/service/group/community?&od=T31&po=89
# https://www.clien.net/service/group/community?&od=T31&po=90
# https://www.clien.net/service/group/community?&od=T31&po=91
# https://www.clien.net/service/group/community?&od=T31&po=92
# https://www.clien.net/service/group/community?&od=T31&po=93
# https://www.clien.net/service/group/community?&od=T31&po=94
# https://www.clien.net/service/group/community?&od=T31&po=95
# https://www.clien.net/service/group/community?&od=T31&po=96
# https://www.clien.net/service/group/community?&od=T31&po=97
# https://www.clien.net/service/group/community?&od=T31&po=98
# https://www.clien.net/service/group/community?&od=T31&po=99

# %%
accum
# Out:
#    추천수  게시판                                      제목  리플수         아이디  조회수  \
# 0    0   모공             ㅂㅅㄹㅊ를 시선차단용 기능으로 사용 중 아닐까요?    0       레메디스트    1
# 1    0   모공                                한화팬 헌정..    0       ROTEM    9
# 2    2   모공                    ●▅▇█▇▆▅▄▇ 누워서 음악듣습니다    0        로얄밀꾸   23
# 3    0   모공            세계 탱크 가격 1위가 의외의 기종이었군요...;;    0         천휘명  290
# 4    0   모공                            우크라이나 여경.jpg    0  MC.JAGAIMO  439
# ..  ..  ...                                     ...  ...         ...  ...
# 25   0   모공           O-<-< 신성조선일보를 비방하면 징계버거 먹습니다.    0         건더기  577
# 26   4   모공  ●▅▇█▇▆▅▄▇ 저는 일베정회원이 쓴 리플 캡쳐한거 올렸는데....   14       비온후하늘  476
# 27   0   모공       클리앙과 디씨를 비교해보면 어쌔신크리드 오디세이가 생각납니다    0        거울행성  322
# 28   0   모공               ●▅▇█▇▆▅▄▇ 클량 왕선비 나왔다고해서..   10        블루바다  282
# 29   0  아질게                               무슨 벌레인가요?    0        예림아빠  212
#
#                      날짜      문서번호 사진유무
# 0   2020-06-04 21:50:54  15037500    N
# 1   2020-06-04 21:50:47  15037499    N
# 2   2020-06-04 21:50:22  15037497    N
# 3   2020-06-04 21:49:33  15037496    N
# 4   2020-06-04 21:49:25  15037495    N
# ..                  ...       ...  ...
# 25  2020-06-04 09:04:04  15033540    N
# 26  2020-06-04 09:04:03  15033539    N
# 27  2020-06-04 09:04:01  15033538    N
# 28  2020-06-04 09:03:58  15033537    N
# 29  2020-06-04 09:03:50  15033536    N
#
# [2997 rows x 9 columns]

# %%
accum.reset_index(inplace = True)

# %%
accum.to_csv('./clien.csv')

# %%
#import pandas as pd
#a = pd.read_csv('./2213.csv')
#b = pd.read_csv('./4389.csv')
#pd.concat([a,b]).to_csv('./clien.csv', index= False)
#a
#b
